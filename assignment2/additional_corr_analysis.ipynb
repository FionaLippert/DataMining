# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression

# %%
train = pd.read_csv('train_clean.csv')

# %%
# remove all target columns except for 'booking_bool'
train.drop(columns=['click_bool','booked_clicked_combined'], inplace=True)

# %%
# create samples that always contain all queries of a srch_id
srch_id_groups = train.groupby('srch_id')
all_srch_ids = train.srch_id.unique()
num_samples = int(0.05*len(all_srch_ids))
train_sample_ids = np.random.choice(all_srch_ids, num_samples, replace=False)
remaining_ids = list(set(all_srch_ids)-set(train_sample_ids))
test_sample_ids = np.random.choice(remaining_ids, num_samples, replace=False)

train_sample = pd.concat([srch_id_groups.get_group(group) for group in train_sample_ids])
test_sample = pd.concat([srch_id_groups.get_group(group) for group in test_sample_ids])

# %%
del train

# %%
mi_position = mutual_info_regression(train_sample.drop(columns=['position','booking_bool']).fillna(-1), train_sample.position)

# %%
corr_position = train.drop(columns=['booking_bool']).corr().position

# %%
corr_booking = train.corr().booking_bool

# %%
df_booking_corr = pd.DataFrame({'corr_booking':corr_booking}, index=train.columns)

# %%
df_booking_corr.sort_values(by='corr_booking', ascending=False)
# Out:
#                                                     corr_booking
# booking_bool                                            1.000000
# prop_desirability                                       0.225748
# prop_desirability_incomplete                            0.218809
# prop_location_score2_norm_srch_destination_id           0.074029
# prop_location_score2_norm_srch_id                       0.073785
# prop_location_score2_norm_site_id                       0.037198
# prop_location_score2                                    0.036707
# promotion_flag                                          0.036047
# prop_review_score_norm_srch_destination_id              0.033439
# prop_review_score_norm_srch_id                          0.031681
# prop_location_score_combined                            0.026994
# avg_prop_review_score                                   0.025936
# prop_review_score                                       0.025936
# prop_review_score_norm_site_id                          0.025356
# avg_prop_location_score2                                0.024938
# prop_location_score1_norm_srch_id                       0.022170
# prop_starrating                                         0.021206
# avg_prop_starrating                                     0.021206
# prop_location_score1_norm_srch_destination_id           0.020557
# price_diff_bins                                         0.020495
# price_diff_filled                                       0.017333
# price_diff                                              0.017333
# star_diff_bool                                          0.015062
# avg_prop_location_score_combined                        0.015027
# srch_query_affinity_bins                                0.011538
# srch_query_affinity_score                               0.010503
# prop_brand_bool                                         0.009991
# srch_room_count                                         0.007948
# srch_saturday_night_bool                                0.005478
# prop_location_score_combined_norm_site_id               0.004237
# ...                                                          ...
# srch_id                                                 0.000487
# prop_location_score_combined_norm_srch_id               0.000258
# willingness_to_pay                                     -0.000090
# prop_id                                                -0.000508
# prop_log_historical_price                              -0.000807
# site_id                                                -0.001354
# prop_location_score_combined_norm_srch_destinat...     -0.001364
# visitor_hist_starrating                                -0.002044
# price_diff_bool                                        -0.002751
# prop_location_score1_norm_site_id                      -0.002779
# orig_destination_distance                              -0.003034
# prop_location_score1                                   -0.003273
# avg_prop_location_score1                               -0.003273
# visitor_hist_starrating_filled                         -0.004754
# srch_adults_count                                      -0.005376
# visitor_hist_adr_usd                                   -0.011189
# visitor_hist_adr_usd_filled                            -0.011189
# avg_prop_price_usd                                     -0.012009
# star_diff_bins                                         -0.018341
# srch_booking_window                                    -0.019582
# star_diff_filled                                       -0.019633
# srch_length_of_stay                                    -0.024412
# price_usd_norm_srch_destination_id                     -0.025503
# price_usd_norm_site_id                                 -0.032187
# price_usd                                              -0.032310
# price_usd_norm_srch_id                                 -0.034496
# star_diff                                              -0.044437
# random_bool                                            -0.088891
# position_estimate                                      -0.134250
# position                                               -0.147918
#
# [65 rows x 1 columns]

# %%
df = pd.DataFrame({'mutual_info':mi_position, 'corr_position':corr_position.drop('position', axis=0)})

# %%
df[df.correlation.abs() > 0.02]

['site_id','prop_country_id','prop_starrating','prop_review_score','prop_brand_bool','prop_location_score2','price_usd','promotion_flag','srch_children_count','srch_room_count','visitor_hist_starrating_filled','star_diff_filled','prop_review_score_norm_srch_destination_id','price_usd_norm_srch_id','price_diff_bins','price_usd_norm_srch_destination_id','prop_location_score1_norm_srch_destination_id','prop_location_score2_norm_srch_destination_id','prop_review_score_norm_srch_id','prop_location_score1_norm_srch_id','prop_location_score2_norm_srch_id','prop_location_score_combined','price_usd_norm_site_id','prop_location_score2_norm_site_id','prop_review_score_norm_site_id','avg_prop_price_usd','avg_prop_location_score2','avg_prop_location_score_combined','avg_prop_review_score','avg_prop_starrating']
# Out:
#                                                correlation  mutual_info
# site_id                                          -0.031194     0.005889
# prop_country_id                                   0.029850     0.001811
# prop_starrating                                  -0.107717     0.006678
# prop_review_score                                -0.053878     0.003331
# prop_brand_bool                                   0.023419     0.001835
# prop_location_score2                             -0.100845     0.020509
# price_usd                                        -0.037268     0.003949
# promotion_flag                                   -0.103621     0.006605
# srch_children_count                              -0.022136     0.001897
# srch_room_count                                  -0.024657     0.000000
# star_diff                                         0.056256     0.000000
# price_diff                                        0.033482     0.002461
# visitor_hist_starrating_filled                   -0.026255     0.000000
# prop_desirability                                -0.205582     0.049785
# star_diff_filled                                  0.026362     0.006599
# price_diff_filled                                 0.033482     0.001845
# prop_review_score_norm_srch_destination_id       -0.088304     0.000000
# price_usd_norm_srch_id                           -0.022634     0.000000
# star_diff_bins                                    0.022387     0.001894
# price_diff_bins                                   0.049414     0.003587
# price_usd_norm_srch_destination_id               -0.054359     0.000000
# prop_location_score1_norm_srch_destination_id    -0.057912     0.011946
# prop_location_score2_norm_srch_destination_id    -0.155900     0.059303
# prop_review_score_norm_srch_id                   -0.088744     0.005315
# prop_location_score1_norm_srch_id                -0.072613     0.000000
# prop_location_score2_norm_srch_id                -0.158667     0.002600
# prop_desirability_incomplete                     -0.199664     0.050565
# position_estimate                                 0.816673     0.630646
# prop_location_score_combined                     -0.116050     0.021687
# price_usd_norm_site_id                           -0.037102     0.002279
# prop_location_score2_norm_site_id                -0.101458     0.006886
# prop_review_score_norm_site_id                   -0.058422     0.008302
# avg_prop_price_usd                               -0.053234     0.047443
# avg_prop_location_score2                         -0.053030     0.051561
# avg_prop_location_score_combined                 -0.079537     0.049671
# avg_prop_review_score                            -0.053878     0.001582
# avg_prop_starrating                              -0.107717     0.006737

# %%
mi_df = pd.DataFrame({'feature':train_sample.drop(columns=['position','booking_bool']).columns, 'mutual_info':mi_position})

# %%
mi_df
# Out:
#                                               feature  mutual_info
# 0                                             srch_id     0.000000
# 1                                             site_id     0.005889
# 2                         visitor_location_country_id     0.000000
# 3                             visitor_hist_starrating     0.000000
# 4                                visitor_hist_adr_usd     0.000000
# 5                                     prop_country_id     0.001811
# 6                                             prop_id     0.045743
# 7                                     prop_starrating     0.006678
# 8                                   prop_review_score     0.003331
# 9                                     prop_brand_bool     0.001835
# 10                               prop_location_score1     0.004560
# 11                               prop_location_score2     0.020509
# 12                          prop_log_historical_price     0.003824
# 13                                          price_usd     0.003949
# 14                                     promotion_flag     0.006605
# 15                                srch_destination_id     0.000000
# 16                                srch_length_of_stay     0.000000
# 17                                srch_booking_window     0.000000
# 18                                  srch_adults_count     0.000489
# 19                                srch_children_count     0.001897
# 20                                    srch_room_count     0.000000
# 21                           srch_saturday_night_bool     0.000000
# 22                          srch_query_affinity_score     0.001832
# 23                          orig_destination_distance     0.000000
# 24                                        random_bool     0.003957
# 25                                          star_diff     0.000000
# 26                                     star_diff_bool     0.000000
# 27                                         price_diff     0.002461
# 28                                    price_diff_bool     0.000000
# 29                     visitor_hist_starrating_filled     0.000000
# ..                                                ...          ...
# 33                                   star_diff_filled     0.006599
# 34                                  price_diff_filled     0.001845
# 35                                              month     0.001528
# 36         prop_review_score_norm_srch_destination_id     0.000000
# 37                             price_usd_norm_srch_id     0.000000
# 38                           srch_query_affinity_bins     0.000000
# 39                                     star_diff_bins     0.001894
# 40                                    price_diff_bins     0.003587
# 41                 price_usd_norm_srch_destination_id     0.000000
# 42      prop_location_score1_norm_srch_destination_id     0.011946
# 43      prop_location_score2_norm_srch_destination_id     0.059303
# 44                     prop_review_score_norm_srch_id     0.005315
# 45                  prop_location_score1_norm_srch_id     0.000000
# 46                  prop_location_score2_norm_srch_id     0.002600
# 47                       prop_desirability_incomplete     0.050565
# 48                                  position_estimate     0.630646
# 49                       prop_location_score_combined     0.021687
# 50  prop_location_score_combined_norm_srch_destina...     0.023705
# 51          prop_location_score_combined_norm_srch_id     0.000000
# 52                             price_usd_norm_site_id     0.002279
# 53                  prop_location_score1_norm_site_id     0.006276
# 54                  prop_location_score2_norm_site_id     0.006886
# 55          prop_location_score_combined_norm_site_id     0.010280
# 56                     prop_review_score_norm_site_id     0.008302
# 57                                 avg_prop_price_usd     0.047443
# 58                           avg_prop_location_score1     0.003162
# 59                           avg_prop_location_score2     0.051561
# 60                   avg_prop_location_score_combined     0.049671
# 61                              avg_prop_review_score     0.001582
# 62                                avg_prop_starrating     0.006737
#
# [63 rows x 2 columns]

# %%
# compare correlations of original and normalized features with 'booking_bool'
features = ['price_usd', 'prop_location_score1', 'prop_location_score2', 'prop_review_score']
norm_features1 = [x + '_norm_srch_id' for x in features]
norm_features2 = [x + '_norm_site_id' for x in features]
norm_features3 = [x + '_norm_srch_destination_id' for x in features]
corr = train[features + ['booking_bool']].corr().booking_bool.drop('booking_bool', axis=0).values
corr_norm1 = train[norm_features1 + ['booking_bool']].corr().booking_bool.drop('booking_bool', axis=0).values
corr_norm2 = train[norm_features2 + ['booking_bool']].corr().booking_bool.drop('booking_bool', axis=0).values
corr_norm3 = train[norm_features3 + ['booking_bool']].corr().booking_bool.drop('booking_bool', axis=0).values
pd.DataFrame({'corr_original':corr, 'corr_norm_srch_id':corr_norm1, 'corr_norm_srch_site_id':corr_norm2, 'corr_norm_srch_dest_id':corr_norm3}, index=features)
# Out:
#                       corr_norm_srch_dest_id  corr_norm_srch_id  \
# price_usd                          -0.025503          -0.034496
# prop_location_score1                0.020557           0.022170
# prop_location_score2                0.074029           0.073785
# prop_review_score                   0.033439           0.031681
#
#                       corr_norm_srch_site_id  corr_original
# price_usd                          -0.032187      -0.032310
# prop_location_score1               -0.002779      -0.003273
# prop_location_score2                0.037198       0.036707
# prop_review_score                   0.025356       0.025936
