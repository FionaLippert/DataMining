# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
db = pd.read_csv('ODI-2018_clean.csv')
db
# Out:
#              timestamp                  programme  ML  IR  stat  DB  gender  \
# 0    4/5/2018 11:22:56                        QRM   0   0     1   0    male
# 1    4/5/2018 11:23:04                         CS   0   0    -1   1    male
# 2    4/5/2018 11:23:06                         BA   1   1     0   1    male
# 3    4/5/2018 11:23:50                         BA   1   1     1   1    male
# 4    4/5/2018 11:23:59                         CS   0   0     0   1    male
# 5    4/5/2018 11:24:34  Drug Discovery and Safety   0   0     1   0    male
# 6    4/5/2018 11:25:25                         CS   1   1     1   0    male
# 7    4/5/2018 11:25:25                        CLS   0   0     1   1    male
# 8    4/5/2018 11:25:36                        EOR   0   0     1   0    male
# 9    4/5/2018 11:25:51             Bioinformatics   1   1    -1   1    male
# 10   4/5/2018 11:25:54                        EOR   0   0     1   0  female
# ...

# %%
#plt.figure(figsize=(16,8))
# plot chart
#ax1 = plt.subplot(121, aspect='equal')

#db.plot(kind='pie', y = 'ML', ax=ax1, autopct='%1.1f%%', 
# startangle=90, shadow=True, legend = False, fontsize=14)
plt.figure()
plt.axis("equal")
db['ML'].value_counts().plot(kind='pie', autopct='%1.1f%%', labels=db['programme'], startangle=90, shadow=False, legend=False)
plt.show()

plt.figure()
plt.axis("equal")
db['programme'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, shadow=False, legend=False)
plt.show()

plt.figure()
#plt.axis("equal")
db['programme'].value_counts().plot(kind='bar', width=2)
plt.show()
